# %% [markdown]
# <a href="https://colab.research.google.com/github/hyeriong/Data_Analysis/blob/main/NAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 데이터분석 기초

# %% [markdown]
# ## Kaggle에서 데이터셋 가져오기
# - https://www.kaggle.com/datasets/sonu1maheshwari/bookingscom
# - booking.com 호텔 데이터셋
#   - 전 세계 220개 이상의 국가 및 지역에서 호텔, 아파트, 별장 등 다양한 숙박 옵션을 제공하는 세계 최고의 온라인 여행사 중 하나인 booking.com의 이름, 평점, 리뷰, 위치를 포함한 호텔 정보를 수집

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-40e1e5a5-5c52-4df0-bfce-695c1e4160b5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-40e1e5a5-5c52-4df0-bfce-695c1e4160b5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
import pandas as pd

# %%
bookings = pd.read_csv(io.BytesIO(uploaded['Bookings.csv']))

# %%
bookings
# Out:
#      Unnamed: 0                                         Hotel_Name  \
# 0             0                     Oakwood Residence Midtown East
# 1             1                            Murray Hill East Suites
# 2             2                           The Herald 8 by LuxUrban
# 3             3  The Cloud One New York-Downtown, by the Motel ...
# 4             4                                   Pod Times Square
# ..          ...                                                ...
# 520         520                Fantastic 3BR At Financial District
# 521         521                3 Bedroom Apartment In Midtown East
# 522         522            2BD 1BA Apartment At Financial District
# 523         523                   2BD 1BA Apartment At Wall Street
# 524         524                   Two BD Apartment At Midtown East
#
#          Review Total_Review  Rating                           Location
# 0       Superb            28     9.1                       Murray Hill
# ...

# %%
bookings.drop(columns = 'Unnamed: 0', inplace = True)  # 불필요한 컬럼 삭제

# %%
bookings.head()
# Out:
#                                           Hotel_Name      Review Total_Review  \
# 0                     Oakwood Residence Midtown East     Superb            28
# 1                            Murray Hill East Suites       Good            52
# 2                           The Herald 8 by LuxUrban       Good         2,870
# 3  The Cloud One New York-Downtown, by the Motel ...  Very good           975
# 4                                   Pod Times Square  Very good        13,951
#
#    Rating                           Location
# 0     9.1                       Murray Hill
# 1     7.6                       Murray Hill
# 2     7.8                         Manhattan
# 3     8.3  Wall Street - Financial District
# 4     8.1                    Hell's Kitchen

# %% [markdown]
# - isnull()
# - isna()

# %%
# 결측치 확인
bookings.isnull().sum()
# Out:
# Hotel_Name        0
# Review          200
# Total_Review    200
# Rating          210
# Location          0
# dtype: int64

# %%
bookings.isna().sum()
# Out:
# Hotel_Name        0
# Review          200
# Total_Review    200
# Rating          210
# Location          0
# dtype: int64

# %%
bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525 entries, 0 to 524
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Hotel_Name    525 non-null    object
#  1   Review        325 non-null    object
#  2   Total_Review  325 non-null    object
#  3   Rating        315 non-null    float64
#  4   Location      525 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 20.6+ KB

# %% [markdown]
# - 거의 절반이 결측치임을 알 수 있다.

# %%
bookings.head(30)
# Out:
#                                            Hotel_Name         Review  \
# 0                      Oakwood Residence Midtown East        Superb
# 1                             Murray Hill East Suites          Good
# 2                            The Herald 8 by LuxUrban          Good
# 3   The Cloud One New York-Downtown, by the Motel ...     Very good
# 4                                    Pod Times Square     Very good
# 5                                      West Side YMCA  Review score
# 6              Hyatt Place New York City/Times Square          Good
# 7                     The Tuscany Powered by LuxUrban          Good
# 8   Hilton Garden Inn New York Central Park South-...          Good
# 9   Crowne Plaza Times Square Manhattan, an IHG Hotel          Good
# 10                    The New Yorker, A Wyndham Hotel          Good
# 11                      The Manhattan at Times Square  Review score
# 12                   Riu Plaza Manhattan Times Square      Fabulous
# ...

# %%
bookings.tail(30)
# Out:
#                                             Hotel_Name Review Total_Review  \
# 495            Exotic 1BR Apartment At Columbus Circle    NaN          NaN
# 496          East Village 2br w wd nr Union Sq NYC-937    NaN          NaN
# 497         Midtown E 2BR w Balcony Gym Doorman NYC-40    NaN          NaN
# 498  Hells Kitchen 2BR w Pool DM nr Central Park NY...    NaN          NaN
# 499     317-1A New Modern 1BR W&D Walk to Central Park    NaN          NaN
# 500  Gramercy Park 2br w wd balcony nr 6 train NYC-947    NaN          NaN
# 501     Tribeca Studio Indoor pool Great views NYC-185    NaN          NaN
# 502    Central Chelsea Studio w Balcony Doorman NYC-34    NaN          NaN
# 503                       Unique 2BR Near Times Square    NaN          NaN
# 504       Studio in Upper Manhattan Great Monthly Deal    NaN          NaN
# 505                                 The Chelsea Escape    NaN          NaN
# ...

# %% [markdown]
# - 호텔 예약 및 평점 데이터이므로, 결측값이 있다는 건 방문율이 낮거나 리뷰 데이터가 없는 호텔일 가능성이 있다.
